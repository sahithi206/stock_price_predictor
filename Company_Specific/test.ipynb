# %%
# Run this once in a cell to install
# !pip install import-ipynb

# Then, use this code to import it (must be in the same folder)
import import_ipynb 
import train # This line loads the notebook and registers it as module 'train'

# Now, import the components directly from the loaded module 'train'
from train import WindowDataset, StockTransformer, DEVICE, WINDOW_SIZE
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import pickle
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score
from tqdm import tqdm


# =====================================================
# CONFIGURATION
# =====================================================
INPUT_DIR = "windows"
MODEL_DIR = "trained_models"
OUTPUT_DIR = "predictions"
BATCH_SIZE = 64
# =====================================================

os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"🚀 Using device: {DEVICE}")

def test_model(company_name, X_test, y_test):
    feature_dim = X_test.shape[2]
    model = StockTransformer(feature_dim).to(DEVICE)
    model_path = os.path.join(MODEL_DIR, f"{company_name}_transformer.pt")

    if not os.path.exists(model_path):
        print(f"❌ Model file not found for {company_name}: {model_path}. Skipping.")
        return

    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.eval()

    test_loader = DataLoader(WindowDataset(X_test, y_test), batch_size=BATCH_SIZE, shuffle=False)
    loss_fn = nn.MSELoss()

    print(f"\n🧪 Testing model for {company_name} | samples={len(X_test)}")

    all_predictions = []
    all_targets = []
    total_loss = 0.0

    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to(DEVICE), y.to(DEVICE)
            pred = model(X)
            loss = loss_fn(pred, y)
            total_loss += loss.item()

            all_predictions.extend(pred.cpu().numpy())
            all_targets.extend(y.cpu().numpy())

    avg_loss = total_loss / len(test_loader) if len(test_loader) > 0 else float('nan')
    print(f"📊 Test Results | MSE: {avg_loss:.6f}")

    scaler_path = os.path.join(INPUT_DIR, f"{company_name}_scaler.pkl")
    if not os.path.exists(scaler_path):
        print(f"❌ Scaler file not found for {company_name}. Cannot denormalize. Saving normalized results.")
        actual_prices = np.array(all_targets)
        predicted_prices = np.array(all_predictions)
    else:
        with open(scaler_path, "rb") as f:
            scaler = pickle.load(f)

        dummy_data = np.zeros((len(all_predictions), scaler.n_features_in_))
        # predicted
        dummy_data[:, 0] = all_predictions
        predicted_denormalized = scaler.inverse_transform(dummy_data)[:, 0]

        # actual
        dummy_data[:, 0] = all_targets
        actual_denormalized = scaler.inverse_transform(dummy_data)[:, 0]

        actual_prices = np.array(actual_denormalized)
        predicted_prices = np.array(predicted_denormalized)
        print("✅ Results denormalized using saved scaler.")

    # ===========================
    # Evaluation Metrics
    # ===========================
    try:
        mae = mean_absolute_error(actual_prices, predicted_prices)
    except Exception:
        mae = float('nan')

    try:
        r2 = r2_score(actual_prices, predicted_prices)
    except Exception:
        r2 = float('nan')

    # MAPE (avoid division by zero)
    mask = actual_prices != 0
    if np.any(mask):
        mape = np.mean(np.abs((actual_prices[mask] - predicted_prices[mask]) / actual_prices[mask])) * 100
    else:
        mape = float('nan')

    # Directional accuracy
    if len(actual_prices) >= 2:
        actual_diff = np.diff(actual_prices)
        pred_diff = np.diff(predicted_prices)
        mask_dir = actual_diff != 0
        if np.sum(mask_dir) > 0:
            directional_accuracy = np.sum((actual_diff[mask_dir] * pred_diff[mask_dir]) > 0) / np.sum(mask_dir) * 100
        else:
            directional_accuracy = float('nan')
    else:
        directional_accuracy = float('nan')

    print("\n📊 Denormalized Test Results:")
    print(f"MAPE: {mape:.2f}%, MAE: {mae:.6f}, R2: {r2:.6f}, Directional Accuracy: {directional_accuracy:.2f}%")

    results_df = pd.DataFrame({
        'Actual_Target': actual_prices,
        'Predicted_Target': predicted_prices
    })

    output_path = os.path.join(OUTPUT_DIR, f"{company_name}_predictions.csv")
    results_df.to_csv(output_path, index=False)
    print(f"💾 Saved predictions for {company_name} → {output_path}")

def main():
    files = [f for f in os.listdir(INPUT_DIR) if f.endswith("_test.pkl")]

    if not files:
        print("❌ No *_test.pkl files found in 'windows'. Run preprocessing first.")
        return

    for file in files:
        company_name = file.replace("_test.pkl", "")
        test_path = os.path.join(INPUT_DIR, file)

        try:
            X_test, y_test = pickle.load(open(test_path, "rb"))
        except Exception as e:
            print(f"⚠️ Error loading {company_name} test data: {e}")
            continue

        if len(X_test) < 1:
            print(f"⚠️ Skipping {company_name}: insufficient test samples ({len(X_test)}).")
            continue

        test_model(company_name, X_test, y_test)

    print("\n✅ Testing complete for all companies.")

if __name__ == "__main__":
    main()
# Out:
# 🚀 Using device: cuda
#
# 🧪 Testing model for AMZN_stock_gdelt_final_train | samples=199
# 📊 Test Results | MSE: 0.000951
# ✅ Results denormalized using saved scaler.
# 💾 Saved predictions for AMZN_stock_gdelt_final_train → predictions/AMZN_stock_gdelt_final_train_predictions.csv
#
# 🧪 Testing model for AAPL_stock_gdelt_final_train | samples=199
# 📊 Test Results | MSE: 0.004814
# ✅ Results denormalized using saved scaler.
# 💾 Saved predictions for AAPL_stock_gdelt_final_train → predictions/AAPL_stock_gdelt_final_train_predictions.csv
#
# 🧪 Testing model for XOM_stock_gdelt_final_train | samples=199
# 📊 Test Results | MSE: 0.000445
# ✅ Results denormalized using saved scaler.
# 💾 Saved predictions for XOM_stock_gdelt_final_train → predictions/XOM_stock_gdelt_final_train_predictions.csv
#
# 🧪 Testing model for V_stock_gdelt_final_train | samples=199
# 📊 Test Results | MSE: 0.000612
# ✅ Results denormalized using saved scaler.
# ...
